# %%
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import re

# %% [markdown]
# # Task 1

# %%
# Generate synthetic IMDB comments for Good, Average, and Bad
good_comments = [f'This movie was fantastic! I loved it. {i}' for i in range(300)]
average_comments = [f'The movie was okay, not great but not bad either. {i}' for i in range(300)]
bad_comments = [f'I did not enjoy this movie at all. It was terrible. {i}' for i in range(300)]

comments = good_comments + average_comments + bad_comments
labels = ['Good'] * 300 + ['Average'] * 300 + ['Bad'] * 300

# Shuffle the data
combined = list(zip(comments, labels))
random.shuffle(combined)
comments, labels = zip(*combined)

# Create DataFrame
df = pd.DataFrame({'comment': comments, 'label': labels})
df.head()
# Out:
#                                              comment    label
# 0  I did not enjoy this movie at all. It was terr...      Bad
# 1  The movie was okay, not great but not bad eith...  Average
# 2  The movie was okay, not great but not bad eith...  Average
# 3  I did not enjoy this movie at all. It was terr...      Bad
# 4  I did not enjoy this movie at all. It was terr...      Bad

# %% [markdown]
# # Task 2 and 3

# %%
def preprocess_text(text):
    text = text.lower()  # Lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove punctuation and numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Apply preprocessing
df['clean_comment'] = df['comment'].apply(preprocess_text)

# Encode labels
le = LabelEncoder()
df['label_encoded'] = le.fit_transform(df['label'])  # Good=2, Average=0, Bad=1 (order may vary)

# One-hot encode the labels for neural network
y = to_categorical(df['label_encoded'])

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(df['clean_comment']).toarray()

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Build the model
model = Sequential()
model.add(Dense(128, input_dim=X.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 classes

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for at least 100 epochs
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# c:\Users\win\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8096 - loss: 0.9607 - val_accuracy: 1.0000 - val_loss: 0.6303
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.5073 - val_accuracy: 1.0000 - val_loss: 0.2226
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1536 - val_accuracy: 1.0000 - val_loss: 0.0528
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 8.2723e-04
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.4445e-04 - val_accuracy: 1.0000 - val_loss: 6.7397e-04
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.0659e-04 - val_accuracy: 1.0000 - val_loss: 5.6373e-04
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.9679e-04 - val_accuracy: 1.0000 - val_loss: 4.8022e-04
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.1617e-04 - val_accuracy: 1.0000 - val_loss: 4.1397e-04
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.4379e-04 - val_accuracy: 1.0000 - val_loss: 3.6086e-04
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.9541e-04 - val_accuracy: 1.0000 - val_loss: 3.1767e-04
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4384e-04 - val_accuracy: 1.0000 - val_loss: 2.8220e-04
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0764e-04 - val_accuracy: 1.0000 - val_loss: 2.5237e-04
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.7948e-04 - val_accuracy: 1.0000 - val_loss: 2.2707e-04
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.4664e-04 - val_accuracy: 1.0000 - val_loss: 2.0561e-04
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.3003e-04 - val_accuracy: 1.0000 - val_loss: 1.8703e-04
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.1025e-04 - val_accuracy: 1.0000 - val_loss: 1.7085e-04
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8804e-04 - val_accuracy: 1.0000 - val_loss: 1.5677e-04
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.7074e-04 - val_accuracy: 1.0000 - val_loss: 1.4435e-04
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.6023e-04 - val_accuracy: 1.0000 - val_loss: 1.3339e-04
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5144e-04 - val_accuracy: 1.0000 - val_loss: 1.2358e-04
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3849e-04 - val_accuracy: 1.0000 - val_loss: 1.1486e-04
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2913e-04 - val_accuracy: 1.0000 - val_loss: 1.0707e-04
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.0371e-05 - val_accuracy: 1.0000 - val_loss: 8.1562e-06
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.2296e-06 - val_accuracy: 1.0000 - val_loss: 7.5381e-06
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.4088e-06 - val_accuracy: 1.0000 - val_loss: 6.9715e-06
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.8171e-06 - val_accuracy: 1.0000 - val_loss: 6.4638e-06
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.3863e-06 - val_accuracy: 1.0000 - val_loss: 5.9678e-06
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.7616e-06 - val_accuracy: 1.0000 - val_loss: 5.5675e-06
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.1525e-06 - val_accuracy: 1.0000 - val_loss: 5.1642e-06
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0854e-06 - val_accuracy: 1.0000 - val_loss: 4.8213e-06
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.7372e-06 - val_accuracy: 1.0000 - val_loss: 4.5859e-06
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2160e-06 - val_accuracy: 1.0000 - val_loss: 4.3371e-06
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0234e-06 - val_accuracy: 1.0000 - val_loss: 4.1782e-06
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.5837e-06 - val_accuracy: 1.0000 - val_loss: 3.9589e-06
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.6019e-06 - val_accuracy: 1.0000 - val_loss: 3.8000e-06
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.3581e-06 - val_accuracy: 1.0000 - val_loss: 3.6763e-06
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.2333e-06 - val_accuracy: 1.0000 - val_loss: 3.4983e-06
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.0228e-06 - val_accuracy: 1.0000 - val_loss: 3.3688e-06
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.8090e-06 - val_accuracy: 1.0000 - val_loss: 3.2201e-06
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.6716e-06 - val_accuracy: 1.0000 - val_loss: 3.1318e-06
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.4460e-06 - val_accuracy: 1.0000 - val_loss: 3.0376e-06
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4837e-06 - val_accuracy: 1.0000 - val_loss: 2.8890e-06
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3509e-06 - val_accuracy: 1.0000 - val_loss: 2.8301e-06
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.2629e-06 - val_accuracy: 1.0000 - val_loss: 2.7359e-06
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.1405e-06 - val_accuracy: 1.0000 - val_loss: 2.6520e-06
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9973e-06 - val_accuracy: 1.0000 - val_loss: 2.5578e-06
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0476e-06 - val_accuracy: 1.0000 - val_loss: 2.4990e-06
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7978e-06 - val_accuracy: 1.0000 - val_loss: 2.4151e-06
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7118e-06 - val_accuracy: 1.0000 - val_loss: 2.3209e-06

# %% [markdown]
# # Task 4

# %%
num_samples = 10
indices = np.random.choice(X_test.shape[0], num_samples, replace=False)
X_sample = X_test[indices]
y_true = y_test[indices]

# Predict
y_pred_probs = model.predict(X_sample, verbose=0)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true_labels = np.argmax(y_true, axis=1)

# Decode labels back to original
predicted_labels = le.inverse_transform(y_pred)
true_labels = le.inverse_transform(y_true_labels)

for i in range(num_samples):
    print(f"Example {i+1}:")
    print(f"Predicted: {predicted_labels[i]}, Actual: {true_labels[i]}")
    print("---")
# Out:
# Example 1:
# Predicted: Bad, Actual: Bad
# ---
# Example 2:
# Predicted: Average, Actual: Average
# ---
# Example 3:
# Predicted: Good, Actual: Good
# ---
# Example 4:
# Predicted: Average, Actual: Average
# ---
# Example 5:
# Predicted: Good, Actual: Good
# ---
# Example 6:
# Predicted: Good, Actual: Good
# ---
# Example 7:
# Predicted: Good, Actual: Good
# ---
# Example 8:
# Predicted: Average, Actual: Average
# ---
# Example 9:
# Predicted: Bad, Actual: Bad
# ---
# Example 10:
# Predicted: Good, Actual: Good
# ---
